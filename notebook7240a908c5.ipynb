# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
plt.style.use('ggplot')

# %%
df = pd.read_csv('../input/data-science-salaries-2023/ds_salaries.csv')

# %%
df.shape
# Out:
# (3755, 11)

# %%
df[['work_year', 'experience_level', 'employment_type', 'job_title',
       'salary', 'salary_in_usd', 'employee_residence',
       'remote_ratio', 'company_location', 'company_size']]
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
#        salary  salary_in_usd employee_residence  remote_ratio  \
# ...

# %%
df = df.rename(columns= {'work_year':'Work Year', 'experience_level': 'Title', 'employment_type':'Employment Type', 'job_title': 'Job Title',
       'salary':'Salary', 'salary_in_usd':'Salary In USD','salary_currency': 'Currency', 'employee_residence':'Country',
       'remote_ratio':'Remote %', 'company_location':'Company Location', 'company_size':'Company Size'})

# %%
df.head(10000)
# Out:
#       Work Year Title Employment Type                 Job Title   Salary  \
# 0          2023    SE              FT  Principal Data Scientist    80000
# 1          2023    MI              CT               ML Engineer    30000
# 2          2023    MI              CT               ML Engineer    25500
# 3          2023    SE              FT            Data Scientist   175000
# 4          2023    SE              FT            Data Scientist   120000
# ...         ...   ...             ...                       ...      ...
# 3750       2020    SE              FT            Data Scientist   412000
# 3751       2021    MI              FT  Principal Data Scientist   151000
# 3752       2020    EN              FT            Data Scientist   105000
# 3753       2020    EN              CT     Business Data Analyst   100000
# 3754       2021    SE              FT      Data Science Manager  7000000
#
#      Currency  Salary In USD Country  Remote % Company Location Company Size
# ...

# %%
df.isna().sum()
# Out:
# Work Year           0
# Title               0
# Employment Type     0
# Job Title           0
# Salary              0
# Currency            0
# Salary In USD       0
# Country             0
# Remote %            0
# Company Location    0
# Company Size        0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3750    False
# 3751    False
# 3752    False
# 3753    False
# 3754    False
# Length: 3755, dtype: bool

# %%
ax = df['Work Year'].value_counts() \
.head(10) \
.plot(kind= 'bar', title ='Top Years Jobs')
ax.set_xlabel('Year')
ax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
df.columns
# Out:
# Index(['Work Year', 'Title', 'Employment Type', 'Job Title', 'Salary',
#        'Currency', 'Salary In USD', 'Country', 'Remote %', 'Company Location',
#        'Company Size'],
#       dtype='object')

# %%
df.plot(kind='scatter',
       x='Remote %',
       y='Salary')
# Out:
# <Axes: xlabel='Remote %', ylabel='Salary'>

# %%
df_corr = df[['Work Year','Salary','Remote %']].corr()
# Out:
#            Work Year    Salary  Remote %
# Work Year   1.000000 -0.094724 -0.236430
# Salary     -0.094724  1.000000  0.028731
# Remote %   -0.236430  0.028731  1.000000

# %%
sns.heatmap(df_corr, annot = True)
# Out:
# <Axes: >
